# %%
# String Data Types in Python 
# string is immutable data type==> it will not change once assigned


h ='hello world'
h.title()
print(h)
# Out:
# hello world

# %%
p = "python"

print(p.isupper())
print(p.islower())
# Out:
# False
# True

# %%
p="python"
p.upper()
print(p)
# Out:
# python

# %%
#alphabetical strings

alp ="hello world"
print(alp.isalpha())

alp1="helloPython"
print(alp1.isalpha())
# Out:
# False
# True

# %%
help(str.upper)
# Out:
# Help on method_descriptor:
#
# upper(self, /) unbound builtins.str method
#     Return a copy of the string converted to uppercase.

# %%
#This is a string
# <h1> Hello Python </h1>==>Find out which method is used to find out the starting word

#startwith
html_data = "<h1>Hello Python</h1>"

print(html_data.startswith("<h1>"))

#endwith
print(html_data.endswith("</h1>"))
# Out:
# True
# True

# %%
UserInput = input("enter user Input")

if UserInput.startswith("<") and UserInput.endswith(">"):
    print("user Input html input")
else:
    print("Good Input")
# Out:
# enter user Input hello ">"
# hello ">"

# %%
#swapcase()

p="pytON"
p.swapcase()

print(p)
# Out:
# pytON

# %%
#find()==>it finds the first occurence

a ="banana"
print(a.find("na"))
# Out:
# 2

# %%
#find all the spaces

a="find all the spaces"
print(a.find(" "))
# Out:
# 4

# %%
#count()

a = str(input("enter input:"))
print(a.count(" "))
# Out:
# enter input hello I am learning Python
# 4

# %%
#reverse a string

a="python"
print(a[::-1])
# Out:
# nohtyp

# %%
#replace
a ="<h1> Hello Python </h1>"

print(a)
print(a.replace('<', "_"))

data1= "I am learning html"
print(data1)
print(data1.replace('html', 'python'))
# Out:
# <h1> Hello Python </h1>
# _h1> Hello Python _/h1>
# I am learning html
# I am learning python

# %%
# space data space
# strip

data=" hello   "
print(data.strip())

#lstrip

print(data.lstrip())

#rstrip

print(data.rstrip())

data1="####hello###"
print(data1.strip('#'))
print(data1.lstrip('#'))
print(data1.rstrip('#'))
# Out:
# hello
# hello
#  hello
# hello
# hello###
# ####hello

# %%
#split()==> breaks a strings into lists of substrings


data ="this is a example of split"

print(data.split())
# Out:
# ['this', 'is', 'a', 'example', 'of', 'split']

# %%
#join()
a = ['hi', 'how', 'are', 'you']
print(' '.join(a))
# Out:
# hi how are you

# %%
#Find length of string
userinput =str(input("Enter string"))
print(len(userinput))
# Out:
# Enter string Lovely
# 6

# %%
#Convert into uppercase/lowercase

user = str(input("enter input"))
print(user.upper())
# Out:
# enter input lovely
# LOVELY

# %%
user = str(input("enter input"))
print(user.lower())
# Out:
# enter input LOVELY
# lovely

# %%
# Count how many times a characters appears
user1 = "LovelyProfessionalUniversity"

print(user1.count('o'))
# Out:
# 3

# %%
# Replace spaces with underscore

userinput= " hello I am Learning Python FullStack "
print(userinput.replace(' ', '_'))
# Out:
# _hello_I_am_Learning_Python_FullStack_

# %%
#check wheter a palindrom or not

userinput= str(input("enter user input: "))

if userinput==userinput[::-1]:
    print("Palindrome")
else:
    print("Non-palindrome")
# Out:
# enter user input:  cat
# Non-palindrome

# %%
# Check if a word exists inside a string

string= "Welcome to Lovely professional university Jaha bachaa 12-12 lakh dekar 24-24 ghante sote h"

if "Lovely" in string:
    print("word exist inside the string")
else:
    print("Not exist")
# Out:
# word exist inside the string

# %%
# Extract the domain from the email
email ="example@gmail.com"

domain = "@" + email.split("@")[1]
print(domain)
# Out:
# @gmail.com

# %%
#Mask email(privacy)
email =input("Enter email")

username, domain= email.split('@')
masked_username = username[:4]+ "****"
masked_email= masked_username+ "@gmail.com"
print(masked_email)
# Out:
# Enter email xyzxyzxyz12@gamil.com
# xyzx****@gmail.com

# %%
#Check password strength
#include digits, atleast one special character, letters


# password= input("enter strong password")

# digits=False
# char=False
# alpha=False

# ch ="/#@!&*^$?|>"

# for name in password:
#     if name.isdigits():
#         digits=True;
#     elif name.is

# %%
x = "mani deep"
print(x[5:])
print(len(x))
# Out:
# deep
# 9
