# %% [markdown]
# # TUPLES

# %%
#Tuple =>mutable

tuple=(1,2,33,42,11)
print(tuple)
# Out:
# (1, 2, 33, 42, 11)

# %% [markdown]
# # DICTIONARY

# %%
print(dir(dict))
# Out:
# ['__class__', '__class_getitem__', '__contains__', '__delattr__', '__delitem__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__ior__', '__iter__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__reduce__', '__reduce_ex__', '__repr__', '__reversed__', '__ror__', '__setattr__', '__setitem__', '__sizeof__', '__str__', '__subclasshook__', 'clear', 'copy', 'fromkeys', 'get', 'items', 'keys', 'pop', 'popitem', 'setdefault', 'update', 'values']

# %%
#Create a dictionary with name,age, rollno, reg no, sem
#len

#dictionary=> unordered, mutable, key-value pair
stuent={
    "name": "Robin",
    "age":  21,
    "reg": 1231512,
    "rollno": 22,
    "sem": 6
    
}
student
print(len(student))
# Out:
# 5

# %%
key_list=["name", "age", "reg", "rollno", "sem"]

values_list = ["Robin", 21, 1231512, 22, 6]

print(key_list)
print(values_list)
# Out:
# ['name', 'age', 'reg', 'rollno', 'sem']
# ['Robin', 21, 1231512, 22, 6]

# %%
student={
    "name": "Robin",
    "age":  21,
    "reg": 1231512,
    "rollno": 22,
    "sem": 6
    
}
student


key=list(student)
values=list(student.values())
print(key)
print(values)
# Out:
# ['name', 'age', 'reg', 'rollno', 'sem']
# ['Robin', 21, 1231512, 22, 6]

# %%
#nested Dictionary
student = {
    "id": 101,
    "name": "Robin",
    "marks": {
        "math": 85,
        "physics": 78,
        "chemistry": 88
    }
}
student
# Out:
# {'id': 101,
#  'name': 'Robin',
#  'marks': {'math': 85, 'physics': 78, 'chemistry': 88}}

# %% [markdown]
# # SET

# %%
print(dir(set))
# Out:
# ['__and__', '__class__', '__class_getitem__', '__contains__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__iand__', '__init__', '__init_subclass__', '__ior__', '__isub__', '__iter__', '__ixor__', '__le__', '__len__', '__lt__', '__ne__', '__new__', '__or__', '__rand__', '__reduce__', '__reduce_ex__', '__repr__', '__ror__', '__rsub__', '__rxor__', '__setattr__', '__sizeof__', '__str__', '__sub__', '__subclasshook__', '__xor__', 'add', 'clear', 'copy', 'difference', 'difference_update', 'discard', 'intersection', 'intersection_update', 'isdisjoint', 'issubset', 'issuperset', 'pop', 'remove', 'symmetric_difference', 'symmetric_difference_update', 'union', 'update']

# %%
#Set =>unordered, mutable

list =[11,22,11,34,22,123]
set1 =set(list)
print(set1)
# Out:
# {123, 34, 11, 22}

# %%
set1= {'rama', 'sanju', 'ram'}
set1.add('raju')
print(set1)
# Out:
# {'raju', 'sanju', 'rama', 'ram'}

# %%
set2={'raj', 'tony' ,'Robin'}
set2.update(set1)
print(set2)
# Out:
# {'raju', 'raj', 'tony', 'sanju', 'rama', 'ram', 'Robin'}

# %%
set_methods= dir(set)
print(set(set_methods))
b = []
for m in set_methods:
    if not(m.startswith('__') and m.endswith('__')):
        b.append(m)
print(set(b))
# Out:
# {'add', 'symmetric_difference_update', '__rand__', '__or__', '__iand__', 'discard', '__and__', '__iter__', 'difference_update', 'issuperset', '__ge__', '__ror__', '__sizeof__', '__lt__', '__getstate__', '__le__', 'clear', 'issubset', 'isdisjoint', '__contains__', '__format__', 'union', '__rsub__', 'symmetric_difference', '__getattribute__', '__setattr__', '__subclasshook__', 'difference', '__hash__', '__reduce__', '__init_subclass__', '__str__', '__delattr__', '__class_getitem__', 'pop', 'update', 'copy', '__ior__', '__gt__', '__dir__', '__eq__', 'intersection_update', '__ixor__', '__new__', '__xor__', '__init__', '__len__', 'remove', '__class__', '__doc__', '__ne__', '__repr__', 'intersection', '__reduce_ex__', '__rxor__', '__isub__', '__sub__'}
# ...

# %% [markdown]
# # LOOPS

# %%
num=int(input("enter your number"))
guess =3
while num!=guess:
    print("enter your number")

# %%
11
2
1
23
3
4
4

# %%
int num =int(input("enter your number"))
guess =4
while num!=guess:
    print("enter again")
    if num==guess:
        print("you won")

# %%
3
